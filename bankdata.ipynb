# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# HYPOTEESI 1: Nuoret käyttää enemmän rahaa suhteessa tuloihin kuin vanhat. WRONG
# HYPOTEESI 2: Iso experience --> isot rahat                                WRONG
# HYPOTEESI 3: Pienituloiset ottaa enemmän lainaa kuin isotuloiset          WRONG
# HYPOTEESI 4:

# %%
# Data Description:								
								
# ID	        Customer ID							
# Age	        Customer's age in completed years							
# Experience	years of professional experience							
# Income	    Annual income of the customer ($000)							
# ZIPCode	    Home Address ZIP code.							
# Family	    Family size of the customer							
# CCAvg	Avg.    spending on credit cards per month ($000)							
# Education	    Education Level. 1: Undergrad; 2: Graduate; 3: Advanced/Professional							
# Mortgage	    Value of house mortgage if any. ($000)							
# Personal Loan	Did this customer accept the personal loan offered in the last campaign?							
# Securities    Account	Does the customer have a securities account with the bank?							
# CD Account	Does the customer have a certificate of deposit (CD) account with the bank?							
# Online	    Does the customer use internet banking facilities?							
# CreditCard	Does the customer use a credit card issued by UniversalBank?							



df = pd.read_csv("C:/Users/elvii/santeri_workstuff/archive/data.csv", index_col=0)
df
# Out:
#       Age  Experience  Income  ZIP Code  Family  CCAvg  Education  Mortgage  \
# ID
# 1      25           1      49     91107       4    1.6          1         0
# 2      45          19      34     90089       3    1.5          1         0
# 3      39          15      11     94720       1    1.0          1         0
# 4      35           9     100     94112       1    2.7          2         0
# 5      35           8      45     91330       4    1.0          2         0
# ...   ...         ...     ...       ...     ...    ...        ...       ...
# 4996   29           3      40     92697       1    1.9          3         0
# 4997   30           4      15     92037       4    0.4          1        85
# 4998   63          39      24     93023       2    0.3          3         0
# 4999   65          40      49     90034       3    0.5          2         0
# 5000   28           4      83     92612       3    0.8          1         0
#
#       Personal Loan  Securities Account  CD Account  Online  CreditCard
# ID
# 1                 0                   1           0       0           0
# 2                 0                   1           0       0           0
# 3                 0                   0           0       0           0
# 4                 0                   0           0       0           0
# 5                 0                   0           0       0           1
# ...             ...                 ...         ...     ...         ...
# 4996              0                   0           0       1           0
# 4997              0                   0           0       1           0
# 4998              0                   0           0       0           0
# 4999              0                   0           0       1           0
# 5000              0                   0           0       1           1
#
# [5000 rows x 13 columns]

# %%
np.min(df.Age)
np.average(df.Age)
# df[df.Age > 44]
# Out:
# 45.3384

# %%
# df[(df.Mortgage < 200) & (df.Income > 30)]
young_df = df[(df.Age < 44) & (df.CCAvg >= 0)]
old_df = df[(df.Age >= 44) & (df.CCAvg >= 0)]

young_income_avg = np.average(young_df.Income)
old_income_avg = np.average(old_df.Income)

young_ccuse_avg = np.average(young_df.CCAvg)
old_ccuse_avg = np.average(old_df.CCAvg)

# young_income = np.sum(young_df.Income)
# old_income = np.sum(old_df.Income)

# young_ccuse = np.sum(young_df.CCAvg)
# old_ccuse = np.sum(old_df.CCAvg)

# print(young_income, old_income)
# print(young_ccuse, old_ccuse)

print("Income avg: ", young_income_avg, old_income_avg)
print("CC use avg: ", young_ccuse_avg, old_ccuse_avg)
# 69911
# 110625


# np.max(ndf)
# Out:
# Income avg:  75.93571114046675 71.9754488823745
# CC use avg:  2.016563921913988 1.8724624404543793

# %%
np.min(df.Income)
ndf = df[(df.Income > df.CCAvg*12*2) & (df.CCAvg > 0.5)]
ndf
# np.average(ndf.Age)
# Out:
#       Age  Experience  Income  ZIP Code  Family     CCAvg  Education  \
# ID
# 1      25           1      49     91107       4  1.600000          1
# 4      35           9     100     94112       1  2.700000          2
# 5      35           8      45     91330       4  1.000000          2
# 7      53          27      72     91711       2  1.500000          2
# 9      35          10      81     90089       3  0.600000          2
# ...   ...         ...     ...       ...     ...       ...        ...
# 4991   55          25      58     95023       4  2.000000          3
# 4992   51          25      92     91330       1  1.900000          2
# 4994   45          21     218     91801       2  6.666667          1
# 4995   64          40      75     94588       3  2.000000          3
# 5000   28           4      83     92612       3  0.800000          1
#
#       Mortgage  Personal Loan  Securities Account  CD Account  Online  \
# ID
# 1            0              0                   1           0       0
# 4            0              0                   0           0       0
# 5            0              0                   0           0       0
# 7            0              0                   0           0       1
# 9          104              0                   0           0       1
# ...        ...            ...                 ...         ...     ...
# 4991       219              0                   0           0       0
# 4992       100              0                   0           0       0
# 4994         0              0                   0           0       1
# 4995         0              0                   0           0       1
# 5000         0              0                   0           0       1
#
#       CreditCard
# ID
# 1              0
# 4              0
# 5              1
# 7              0
# 9              0
# ...          ...
# 4991           1
# 4992           1
# 4994           0
# 4995           0
# 5000           1
#
# [2847 rows x 13 columns]

# %%
# df[(df.Income > df.Experience*5 + 35) & (df.Experience >= 10)]

bigexp_df = df[df.Experience >= 10]
smallexp_df = df[df.Experience < 10]

print("Sizes: ", bigexp_df.shape, smallexp_df.shape)

bigexp_avg_income = np.average(bigexp_df.Income)
smallexp_avg_income = np.average(smallexp_df.Income)

bigexp_median_income = np.median(bigexp_df.Income)
smallexp_median_income = np.median(smallexp_df.Income)

print("Avg incmes: ", bigexp_avg_income, smallexp_avg_income)
print("Avg incmes: ", bigexp_median_income, smallexp_median_income)
# Out:
# Sizes:  (3829, 13) (1171, 13)
# Avg incmes:  73.12744841995298 75.88898377455166
# Avg incmes:  63.0 68.0

# %%
import seaborn as sns
from sklearn.preprocessing import scale

mydata_std = pd.DataFrame(df, index=df.index, columns=df.columns)

mydata_std.describe()

corr = mydata_std.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)

# sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
#             square=True)
# Out:
# C:\Users\elvii\AppData\Local\Temp\ipykernel_21660\4179023238.py:9: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# <style type="text/css">
# #T_a1c26_row0_col0, #T_a1c26_row1_col1, #T_a1c26_row2_col2, #T_a1c26_row3_col3, #T_a1c26_row4_col4, #T_a1c26_row5_col5, #T_a1c26_row6_col6, #T_a1c26_row7_col7, #T_a1c26_row8_col8, #T_a1c26_row9_col9, #T_a1c26_row10_col10, #T_a1c26_row11_col11, #T_a1c26_row12_col12 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a1c26_row0_col1, #T_a1c26_row1_col0 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_a1c26_row0_col2 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_a1c26_row0_col3, #T_a1c26_row0_col8, #T_a1c26_row0_col10, #T_a1c26_row1_col3, #T_a1c26_row1_col8, #T_a1c26_row1_col10, #T_a1c26_row2_col0, #T_a1c26_row2_col4, #T_a1c26_row2_col6, #T_a1c26_row4_col1, #T_a1c26_row5_col0, #T_a1c26_row5_col1, #T_a1c26_row6_col2, #T_a1c26_row6_col5, #T_a1c26_row6_col7, #T_a1c26_row6_col11, #T_a1c26_row9_col12, #T_a1c26_row12_col9 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_
{
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_a1c26_row8_col6, #T_a1c26_row12_col10 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_a1c26_row8_col10, #T_a1c26_row9_col10 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_a1c26_row9_col0 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_a1c26_row9_col1, #T_a1c26_row10_col3 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_a1c26_row9_col2, #T_a1c26_row9_col4, #T_a1c26_row12_col2 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_a1c26_row9_col5 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_a1c26_row10_col2 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_a1c26_row10_col5 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_a1c26_row10_col8 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_a1c26_row10_col9 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_a1c26_row10_col12 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_a1c26_row11_col0, #T_a1c26_row11_col1 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_a1c26_row12_col1 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a1c26">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a1c26_level0_col0" class="col_heading level0 col0" >Age</th>
#       <th id="T_a1c26_level0_col1" class="col_heading level0 col1" >Experience</th>
#       <th id="T_a1c26_level0_col2" class="col_heading level0 col2" >Income</th>
#       <th id="T_a1c26_level0_col3" class="col_heading level0 col3" >ZIP Code</th>
#       <th id="T_a1c26_level0_col4" class="col_heading level0 col4" >Family</th>
#       <th id="T_a1c26_level0_col5" class="col_heading level0 col5" >CCAvg</th>
#       <th id="T_a1c26_level0_col6" class="col_heading level0 col6" >Education</th>
#       <th id="T_a1c26_level0_col7" class="col_heading level0 col7" >Mortgage</th>
#       <th id="T_a1c26_level0_col8" class="col_heading level0 col8" >Personal Loan</th>
#       <th id="T_a1c26_level0_col9" class="col_heading level0 col9" >Securities Account</th>
#       <th id="T_a1c26_level0_col10" class="col_heading level0 col10" >CD Account</th>
#       <th id="T_a1c26_level0_col11" class="col_heading level0 col11" >Online</th>
#       <th id="T_a1c26_level0_col12" class="col_heading level0 col12" >CreditCard</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a1c26_level0_row0" class="row_heading level0 row0" >Age</th>
#       <td id="T_a1c26_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_a1c26_row0_col1" class="data row0 col1" >0.99</td>
#       <td id="T_a1c26_row0_col2" class="data row0 col2" >-0.06</td>
#       <td id="T_a1c26_row0_col3" class="data row0 col3" >-0.03</td>
#       <td id="T_a1c26_row0_col4" class="data row0 col4" >-0.05</td>
#       <td id="T_a1c26_row0_col5" class="data row0 col5" >-0.05</td>
#       <td id="T_a1c26_

# %%
ploan_df = df[df["Personal Loan"] > 0]
ploan_df[ploan_df.Income > 100]
# Out:
#       Age  Experience  Income  ZIP Code  Family  CCAvg  Education  Mortgage  \
# ID
# 10     34           9     180     93023       1    8.9          3         0
# 17     38          14     130     95010       4    4.7          3       134
# 19     46          21     193     91604       2    8.1          3         0
# 30     38          13     119     94104       1    3.3          2         0
# 39     42          18     141     94114       3    5.0          3         0
# ...   ...         ...     ...       ...     ...    ...        ...       ...
# 4884   38          13     129     92646       3    4.1          3         0
# 4928   43          19     121     94720       1    0.7          2         0
# 4942   28           4     112     90049       2    1.6          2         0
# 4963   46          20     122     90065       3    3.0          3         0
# 4981   29           5     135     95762       3    5.3          1         0
#
#       Personal Loan  Securities Account  CD Account  Online  CreditCard
# ID
# 10                1                   0           0       0           0
# 17                1                   0           0       0           0
# 19                1                   0           0       0           0
# 30                1                   0           1       1           1
# 39                1                   1           1       1           0
# ...             ...                 ...         ...     ...         ...
# 4884              1                   0           1       1           1
# 4928              1                   0           1       1           1
# 4942              1                   0           0       1           0
# 4963              1                   0           1       1           1
# 4981              1                   0           1       1           1
#
# [438 rows x 13 columns]
