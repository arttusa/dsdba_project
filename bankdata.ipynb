# %%
import pandas as pd
import numpy as np
import seaborn as sns
import pymongo
from pymongo import MongoClient
conn = MongoClient()

# %%
# HYPOTEESI 1: Nuoret käyttää enemmän rahaa suhteessa tuloihin kuin vanhat. WRONG
# HYPOTEESI 2: Iso experience --> isot rahat                                WRONG
# HYPOTEESI 3: Pienituloiset ottaa enemmän lainaa kuin isotuloiset          WRONG
# HYPOTEESI 4:

# %%
# Data Description:								
								
# ID	        Customer ID							
# Age	        Customer's age in completed years							
# Experience	years of professional experience							
# Income	    Annual income of the customer ($000)							
# ZIPCode	    Home Address ZIP code.							
# Family	    Family size of the customer							
# CCAvg	Avg.    spending on credit cards per month ($000)							
# Education	    Education Level. 1: Undergrad; 2: Graduate; 3: Advanced/Professional							
# Mortgage	    Value of house mortgage if any. ($000)							
# Personal Loan	Did this customer accept the personal loan offered in the last campaign?							
# Securities    Account	Does the customer have a securities account with the bank?							
# CD Account	Does the customer have a certificate of deposit (CD) account with the bank?							
# Online	    Does the customer use internet banking facilities?							
# CreditCard	Does the customer use a credit card issued by UniversalBank?							
db = conn.bank_loans


df = pd.DataFrame(db.bank_loans.find({}))
df
# Out:
#                            _id    ID  Age  Experience  Income  ZIP Code  \
# 0     6480a905c432eda27afda351     1   25           1      49     91107
# 1     6480a905c432eda27afda352     2   45          19      34     90089
# 2     6480a905c432eda27afda353     3   39          15      11     94720
# 3     6480a905c432eda27afda354     4   35           9     100     94112
# 4     6480a905c432eda27afda355     5   35           8      45     91330
# ...                        ...   ...  ...         ...     ...       ...
# 4995  6480a906c432eda27afdb6d4  4996   29           3      40     92697
# 4996  6480a906c432eda27afdb6d5  4997   30           4      15     92037
# 4997  6480a906c432eda27afdb6d6  4998   63          39      24     93023
# 4998  6480a906c432eda27afdb6d7  4999   65          40      49     90034
# 4999  6480a906c432eda27afdb6d8  5000   28           4      83     92612
#
#       Family  CCAvg  Education  Mortgage  Personal Loan  Securities Account  \
# 0          4    1.6          1         0              0                   1
# 1          3    1.5          1         0              0                   1
# 2          1    1.0          1         0              0                   0
# 3          1    2.7          2         0              0                   0
# 4          4    1.0          2         0              0                   0
# ...      ...    ...        ...       ...            ...                 ...
# 4995       1    1.9          3         0              0                   0
# 4996       4    0.4          1        85              0                   0
# 4997       2    0.3          3         0              0                   0
# 4998       3    0.5          2         0              0                   0
# 4999       3    0.8          1         0              0                   0
#
#       CD Account  Online  CreditCard
# 0              0       0           0
# 1              0       0           0
# 2              0       0           0
# 3              0       0           0
# 4              0       0           1
# ...          ...     ...         ...
# 4995           0       1           0
# 4996           0       1           0
# 4997           0       0           0
# 4998           0       1           0
# 4999           0       1           1
#
# [5000 rows x 15 columns]

# %%
np.min(df.Age)
np.average(df.Age)
# df[df.Age > 44]
# Out:
# 45.3384

# %%
# df[(df.Mortgage < 200) & (df.Income > 30)]
young_df = df[(df.Age < 44) & (df.CCAvg >= 0)]
old_df = df[(df.Age >= 44) & (df.CCAvg >= 0)]

young_income_avg = np.average(young_df.Income)
old_income_avg = np.average(old_df.Income)

young_ccuse_avg = np.average(young_df.CCAvg)
old_ccuse_avg = np.average(old_df.CCAvg)

# young_income = np.sum(young_df.Income)
# old_income = np.sum(old_df.Income)

# young_ccuse = np.sum(young_df.CCAvg)
# old_ccuse = np.sum(old_df.CCAvg)

# print(young_income, old_income)
# print(young_ccuse, old_ccuse)

print("Income avg: ", young_income_avg, old_income_avg)
print("CC use avg: ", young_ccuse_avg, old_ccuse_avg)
# 69911
# 110625


# np.max(ndf)
# Out:
# Income avg:  75.93571114046675 71.9754488823745
# CC use avg:  2.016563921913988 1.8724624404543793

# %%
np.min(df.Income)
ndf = df[(df.Income > df.CCAvg*12*2) & (df.CCAvg > 0.5)]
ndf
# np.average(ndf.Age)
# Out:
#                            _id    ID  Age  Experience  Income  ZIP Code  \
# 0     6480a905c432eda27afda351     1   25           1      49     91107
# 3     6480a905c432eda27afda354     4   35           9     100     94112
# 4     6480a905c432eda27afda355     5   35           8      45     91330
# 6     6480a905c432eda27afda357     7   53          27      72     91711
# 8     6480a905c432eda27afda359     9   35          10      81     90089
# ...                        ...   ...  ...         ...     ...       ...
# 4990  6480a906c432eda27afdb6cf  4991   55          25      58     95023
# 4991  6480a906c432eda27afdb6d0  4992   51          25      92     91330
# 4993  6480a906c432eda27afdb6d2  4994   45          21     218     91801
# 4994  6480a906c432eda27afdb6d3  4995   64          40      75     94588
# 4999  6480a906c432eda27afdb6d8  5000   28           4      83     92612
#
#       Family     CCAvg  Education  Mortgage  Personal Loan  \
# 0          4  1.600000          1         0              0
# 3          1  2.700000          2         0              0
# 4          4  1.000000          2         0              0
# 6          2  1.500000          2         0              0
# 8          3  0.600000          2       104              0
# ...      ...       ...        ...       ...            ...
# 4990       4  2.000000          3       219              0
# 4991       1  1.900000          2       100              0
# 4993       2  6.666667          1         0              0
# 4994       3  2.000000          3         0              0
# 4999       3  0.800000          1         0              0
#
#       Securities Account  CD Account  Online  CreditCard
# 0                      1           0       0           0
# 3                      0           0       0           0
# 4                      0           0       0           1
# 6                      0           0       1           0
# 8                      0           0       1           0
# ...                  ...         ...     ...         ...
# 4990                   0           0       0           1
# 4991                   0           0       0           1
# 4993                   0           0       1           0
# 4994                   0           0       1           0
# 4999                   0           0       1           1
#
# [2847 rows x 15 columns]

# %%
# df[(df.Income > df.Experience*5 + 35) & (df.Experience >= 10)]

bigexp_df = df[df.Experience >= 10]
smallexp_df = df[df.Experience < 10]

print("Sizes: ", bigexp_df.shape, smallexp_df.shape)

bigexp_avg_income = np.average(bigexp_df.Income)
smallexp_avg_income = np.average(smallexp_df.Income)

bigexp_median_income = np.median(bigexp_df.Income)
smallexp_median_income = np.median(smallexp_df.Income)

print("Avg incmes: ", bigexp_avg_income, smallexp_avg_income)
print("Avg incmes: ", bigexp_median_income, smallexp_median_income)
# Out:
# Sizes:  (3829, 15) (1171, 15)
# Avg incmes:  73.12744841995298 75.88898377455166
# Avg incmes:  63.0 68.0

# %%
import seaborn as sns
from sklearn.preprocessing import scale

mydata_std = pd.DataFrame(df, index=df.index, columns=df.columns)

mydata_std.describe()

corr = mydata_std.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)

# sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
#             square=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 2
#       1 import seaborn as sns
# ----> 2 from sklearn.preprocessing import scale
#       4 mydata_std = pd.DataFrame(df, index=df.index, columns=df.columns)
#       6 mydata_std.describe()
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
ploan_df = df[df["Personal Loan"] > 0]
ploan_df[ploan_df.Income > 100]
# Out:
#                            _id    ID  Age  Experience  Income  ZIP Code  \
# 9     6480a905c432eda27afda35a    10   34           9     180     93023
# 16    6480a905c432eda27afda361    17   38          14     130     95010
# 18    6480a905c432eda27afda363    19   46          21     193     91604
# 29    6480a905c432eda27afda36e    30   38          13     119     94104
# 38    6480a905c432eda27afda377    39   42          18     141     94114
# ...                        ...   ...  ...         ...     ...       ...
# 4883  6480a906c432eda27afdb664  4884   38          13     129     92646
# 4927  6480a906c432eda27afdb690  4928   43          19     121     94720
# 4941  6480a906c432eda27afdb69e  4942   28           4     112     90049
# 4962  6480a906c432eda27afdb6b3  4963   46          20     122     90065
# 4980  6480a906c432eda27afdb6c5  4981   29           5     135     95762
#
#       Family  CCAvg  Education  Mortgage  Personal Loan  Securities Account  \
# 9          1    8.9          3         0              1                   0
# 16         4    4.7          3       134              1                   0
# 18         2    8.1          3         0              1                   0
# 29         1    3.3          2         0              1                   0
# 38         3    5.0          3         0              1                   1
# ...      ...    ...        ...       ...            ...                 ...
# 4883       3    4.1          3         0              1                   0
# 4927       1    0.7          2         0              1                   0
# 4941       2    1.6          2         0              1                   0
# 4962       3    3.0          3         0              1                   0
# 4980       3    5.3          1         0              1                   0
#
#       CD Account  Online  CreditCard
# 9              0       0           0
# 16             0       0           0
# 18             0       0           0
# 29             1       1           1
# 38             1       1           0
# ...          ...     ...         ...
# 4883           1       1           1
# 4927           1       1           1
# 4941           0       1           0
# 4962           1       1           1
# 4980           1       1           1
#
# [438 rows x 15 columns]

# %%
# Internet usage

young_df = df[(df.Age < 44) & (df.CCAvg >= 0)]
old_df = df[(df.Age >= 44) & (df.CCAvg >= 0)]

young_internet_usage = young_df[young_df.Online == 1]
old_internet_usage = old_df[old_df.Online == 0]

young_internet_usage
# Out:
#                            _id    ID  Age  Experience  Income  ZIP Code  \
# 5     6480a905c432eda27afda356     6   37          13      29     92121
# 8     6480a905c432eda27afda359     9   35          10      81     90089
# 11    6480a905c432eda27afda35c    12   29           5      45     90277
# 22    6480a905c432eda27afda367    23   29           5      62     90277
# 25    6480a905c432eda27afda36a    26   43          19      29     94305
# ...                        ...   ...  ...         ...     ...       ...
# 4981  6480a906c432eda27afdb6c6  4982   34           9     195     90266
# 4989  6480a906c432eda27afdb6ce  4990   24           0      38     93555
# 4995  6480a906c432eda27afdb6d4  4996   29           3      40     92697
# 4996  6480a906c432eda27afdb6d5  4997   30           4      15     92037
# 4999  6480a906c432eda27afdb6d8  5000   28           4      83     92612
#
#       Family  CCAvg  Education  Mortgage  Personal Loan  Securities Account  \
# 5          4    0.4          2       155              0                   0
# 8          3    0.6          2       104              0                   0
# 11         3    0.1          2         0              0                   0
# 22         1    1.2          1       260              0                   0
# 25         3    0.5          1        97              0                   0
# ...      ...    ...        ...       ...            ...                 ...
# 4981       2    3.0          1       122              0                   0
# 4989       1    1.0          3         0              0                   0
# 4995       1    1.9          3         0              0                   0
# 4996       4    0.4          1        85              0                   0
# 4999       3    0.8          1         0              0                   0
#
#       CD Account  Online  CreditCard
# 5              0       1           0
# 8              0       1           0
# 11             0       1           0
# 22             0       1           0
# 25             0       1           0
# ...          ...     ...         ...
# 4981           0       1           0
# 4989           0       1           0
# 4995           0       1           0
# 4996           0       1           0
# 4999           0       1           1
#
# [1339 rows x 15 columns]
